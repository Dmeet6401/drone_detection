# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pwd
# Out:
# '/content'

# %%
# %cd /content/drive/MyDrive/tasks/drone_object
# Out:
# /content/drive/MyDrive/tasks/drone_object

# %%
! pip install -qr https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt
# Out:
#      |████████████████████████████████| 1.6 MB 5.1 MB/s

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image

# %%
# !git clone https://github.com/ultralytics/yolov5

# %%
# %cd yolov5
# %pip install -qr requirements.txt  # install
# Out:
# /content/drive/MyDrive/tasks/drone_object/yolov5

# %%
import torch
import utils
display = utils.notebook_init()
# Out:
# YOLOv5 🚀 v6.2-240-gabbfd69 Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 22.6/78.2 GB disk)

# %%
# !python train.py --img 608 --batch 16 --epochs 30 --data coco.yaml --weights runs/train/exp13/weights/best.pt --cache
# Out:
# train: weights=runs/train/exp13/weights/best.pt, cfg=, data=coco.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=30, batch_size=16, imgsz=608, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 3 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.2-240-gabbfd69 Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %% [markdown]
# validate yolov5s on coco val

# %%
# !python val.py --weights runs/train/exp14/weights/best.pt --data data/coco.yaml --img 416 --half
# Out:
# val: data=data/coco.yaml, weights=['runs/train/exp14/weights/best.pt'], batch_size=32, imgsz=416, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=True, project=runs/val, name=exp, exist_ok=False, half=True, dnn=False
# requirements: YOLOv5 requirement "ipython" not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#
# requirements: 1 package updated per /content/drive/MyDrive/tasks/drone_object/yolov5/requirements.txt
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# YOLOv5 🚀 v6.2-240-gabbfd69 Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients
# ...
# 100% 755k/755k [00:00<00:00, 49.9MB/s]
# ...

# %%
# !python detect.py --weights runs/train/exp14/weights/best.pt --img 416 --conf 0.25 --source testing_data/download.jpeg
# Out:
# detect: weights=['runs/train/exp14/weights/best.pt'], source=testing_data/download.jpeg, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-240-gabbfd69 Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients
# image 1/1 /content/drive/MyDrive/tasks/drone_object/yolov5/testing_data/download.jpeg: 288x416 1 drone, 12.2ms
# Speed: 0.4ms pre-process, 12.2ms inference, 1.3ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/exp2

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(20,20))
plt.axis(True)
processed_img = plt.imread('runs/detect/exp2/download.jpeg')
plt.imshow(processed_img)
plt.show()
